# %%
# TPU를 정상적으로 사용하기 위해서는 tensorflow 1.31.1 버전을 사용해야 합니다.
# 2019.7 기준 Google Colab에서는 tensorflow 1.14.0이 설치되어 있습니다.
# !pip uninstall tensorflow
# !pip install tensorflow==1.13.1

# %%
# 패키지 임포트
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Activation, Dense, Dropout, Conv2D, Flatten, MaxPool2D
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 데이터 세트 준비
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
# 데이터 세트 셰이프 확인
print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
# 데이터 세트 이미지 확인
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(train_images[i])
plt.show()

# %%
# 데이터 세트 라벨 확인
print(train_labels[0:10])
# Out:
# [[6]
#  [9]
#  [9]
#  [4]
#  [1]
#  [1]
#  [2]
#  [7]
#  [8]
#  [3]]

# %%
# 데이터 세트 이미지 전처리
train_images = train_images.astype('float32')/255.0
test_images = test_images.astype('float32')/255.0

# 데이터 세트 이미지 전처리 후 셰이프 확인
print(train_images.shape)
print(test_images.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
# 데이터 세트 라벨 전처리
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

# 데이터 세트 라벨 전처리 후 셰이프 확인
print(train_labels.shape)
print(test_labels.shape)
# Out:
# (50000, 10)
# (10000, 10)

# %%
# 모델 생성
model = Sequential()

# Conv→Conv→Pool→Dropout
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Conv→Conv→Pool→Dropout
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flatten→Dense→Dropout→Dense
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %%
# TPU 모델 편환
import tensorflow as tf
import os
tpu_model = tf.contrib.tpu.keras_to_tpu_model(
    model,
    strategy=tf.contrib.tpu.TPUDistributionStrategy(
        tf.contrib.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])
    )
)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:Querying Tensorflow master (grpc://10.86.186.66:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 10384614962093410999)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 5381721351096368593)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 4527332874510416682)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 7245834548977838503)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 2967470932368888567)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 15785667202869789504)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 9391685263104832411)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 16643861893492144089)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 388645661355190960)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 17046682534768621238)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 17006325693255405490)
# WARNING:tensorflow:tpu_model (from tensorflow.contrib.tpu.python.tpu.keras_support) is experimental and may change or be removed at any time, and without warning.

# %%
# 컴파일
tpu_model.compile(loss='categorical_crossentropy', optimizer=Adam(lr=0.001), metrics=['acc'])
# Out:
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}

# %%
# 학습
history = tpu_model.fit(train_images, train_labels, batch_size=128,
    epochs=20, validation_split=0.1)
# Out:
# Train on 50000 samples, validate on 5000 samples
# Epoch 1/20
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(16,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(16, 32, 32, 3), dtype=tf.float32, name='conv2d_4_input_10'), TensorSpec(shape=(16, 10), dtype=tf.float32, name='dense_3_target_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Remapping placeholder for conv2d_4_input
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/tpu/python/tpu/keras_support.py:302: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f76e3000e80> []
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 4.201892614364624 secs
# INFO:tensorflow:Setting weights on TPU model.
# INFO:tensorflow:CPU -> TPU lr: 0.0010000000474974513 {0.001}
# INFO:tensorflow:CPU -> TPU beta_1: 0.8999999761581421 {0.9}
# INFO:tensorflow:CPU -> TPU beta_2: 0.9990000128746033 {0.999}
# INFO:tensorflow:CPU -> TPU decay: 0.0 {0.0}
# WARNING:tensorflow:Cannot update non-variable config: epsilon
# WARNING:tensorflow:Cannot update non-variable config: amsgrad
# 49536/50000 [============================>.] - ETA: 0s - loss: 1.6221 - acc: 0.4058INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(10,), dtype=tf.int32, name='core_id0'), TensorSpec(shape=(10, 32, 32, 3), dtype=tf.float32, name='conv2d_4_input_10'), TensorSpec(shape=(10, 10), dtype=tf.float32, name='dense_3_target_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_4_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f76e3000e80> [<tf.Variable 'tpu_140148595893696/Adam/iterations:0' shape=() dtype=int64>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e2397ef0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e2354cc0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e23541d0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e237bd30>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e22bee48>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e2250cc0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e22174a8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e21e1f98>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e2183be0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e214af98>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e21709e8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e20834e0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e204b278>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e206f278>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1fe1978>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1fa6e80>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1f39d30>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1edb630>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1ea3748>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1e6c390>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1e36e10>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1d9ff98>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1d6c438>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1d31710>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1ca1dd8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1c46cc0>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1c31e48>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1bfa518>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1b422e8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1b0be48>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1af9e48>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1a42518>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1a092e8>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e19d1e48>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e193de48>, <tensorflow.contrib.tpu.python.tpu.keras_tpu_variables.ReplicatedVariable object at 0x7f76e1907518>]
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 3.6099019050598145 secs
# 49920/50000 [============================>.] - ETA: 0s - loss: 1.6205 - acc: 0.4065INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(16,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(16, 32, 32, 3), dtype=tf.float32, name='conv2d_4_input_10'), TensorSpec(shape=(16, 10), dtype=tf.float32, name='dense_3_target_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Remapping placeholder for conv2d_4_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f76df8547b8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 2.511253595352173 secs
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(1,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(1, 32, 32, 3), dtype=tf.float32, name='conv2d_4_input_10'), TensorSpec(shape=(1, 10), dtype=tf.float32, name='dense_3_target_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_4_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f76df8547b8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 1.5113716125488281 secs
# 50000/50000 [==============================] - 35s 708us/sample - loss: 1.6199 - acc: 0.4066 - val_loss: 2.6500 - val_acc: 0.2618
# Epoch 2/20
# 50000/50000 [==============================] - 10s 201us/sample - loss: 1.2390 - acc: 0.5573 - val_loss: 2.0544 - val_acc: 0.3430
# Epoch 3/20
# 50000/50000 [==============================] - 10s 208us/sample - loss: 1.0551 - acc: 0.6265 - val_loss: 2.8759 - val_acc: 0.2642
# Epoch 4/20
# 50000/50000 [==============================] - 10s 198us/sample - loss: 0.9572 - acc: 0.6650 - val_loss: 1.6897 - val_acc: 0.4488
# Epoch 5/20
# 50000/50000 [==============================] - 10s 191us/sample - loss: 0.8407 - acc: 0.7029 - val_loss: 1.5344 - val_acc: 0.4934
# Epoch 6/20
# 50000/50000 [==============================] - 9s 190us/sample - loss: 0.7717 - acc: 0.7303 - val_loss: 1.2292 - val_acc: 0.5792
# Epoch 7/20
# 50000/50000 [==============================] - 10s 194us/sample - loss: 0.7050 - acc: 0.7530 - val_loss: 1.1785 - val_acc: 0.5986
# Epoch 8/20
# 50000/50000 [==============================] - 10s 195us/sample - loss: 0.6557 - acc: 0.7681 - val_loss: 1.0139 - val_acc: 0.6632
# Epoch 9/20
# 50000/50000 [==============================] - 10s 196us/sample - loss: 0.6146 - acc: 0.7822 - val_loss: 0.9786 - val_acc: 0.6796
# Epoch 10/20
# 50000/50000 [==============================] - 9s 190us/sample - loss: 0.5747 - acc: 0.7973 - val_loss: 0.6479 - val_acc: 0.7764
# Epoch 11/20
# 50000/50000 [==============================] - 9s 190us/sample - loss: 0.5334 - acc: 0.8114 - val_loss: 0.4508 - val_acc: 0.8436
# Epoch 12/20
# 50000/50000 [==============================] - 10s 192us/sample - loss: 0.5033 - acc: 0.8211 - val_loss: 0.3946 - val_acc: 0.8560
# Epoch 13/20
# 50000/50000 [==============================] - 10s 194us/sample - loss: 0.4748 - acc: 0.8313 - val_loss: 0.5069 - val_acc: 0.8172
# Epoch 14/20
# 50000/50000 [==============================] - 10s 194us/sample - loss: 0.4533 - acc: 0.8381 - val_loss: 0.4811 - val_acc: 0.8294
# Epoch 15/20
# 50000/50000 [==============================] - 9s 185us/sample - loss: 0.4275 - acc: 0.8468 - val_loss: 0.4841 - val_acc: 0.8218
# Epoch 16/20
# 50000/50000 [==============================] - 9s 188us/sample - loss: 0.4106 - acc: 0.8536 - val_loss: 0.3855 - val_acc: 0.8578
# Epoch 17/20
# 50000/50000 [==============================] - 10s 202us/sample - loss: 0.3869 - acc: 0.8612 - val_loss: 0.2580 - val_acc: 0.9086
# Epoch 18/20
# 50000/50000 [==============================] - 10s 197us/sample - loss: 0.3676 - acc: 0.8692 - val_loss: 0.2076 - val_acc: 0.9336
# Epoch 19/20
# 50000/50000 [==============================] - 10s 196us/sample - loss: 0.3542 - acc: 0.8726 - val_loss: 0.2157 - val_acc: 0.9260
# Epoch 20/20
# 50000/50000 [==============================] - 9s 188us/sample - loss: 0.3361 - acc: 0.8792 - val_loss: 0.1267 - val_acc: 0.9664

# %%
# 그래프 표시
plt.plot(history.history['acc'], label='acc')
plt.plot(history.history['val_acc'], label='val_acc')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(loc='best')
plt.show()

# %%
# 평가
test_loss, test_acc = tpu_model.evaluate(test_images, test_labels)
print('loss: {:.3f}\nacc: {:.3f}'.format(test_loss, test_acc ))
# Out:
# INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(4,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(4, 32, 32, 3), dtype=tf.float32, name='conv2d_4_input_10'), TensorSpec(shape=(4, 10), dtype=tf.float32, name='dense_3_target_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_4_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f76df8547b8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 1.6535284519195557 secs
#  9984/10000 [============================>.] - ETA: 0s - loss: 0.6476 - acc: 0.7973INFO:tensorflow:New input shapes; (re-)compiling: mode=eval (# of cores 8), [TensorSpec(shape=(2,), dtype=tf.int32, name='core_id_10'), TensorSpec(shape=(2, 32, 32, 3), dtype=tf.float32, name='conv2d_4_input_10'), TensorSpec(shape=(2, 10), dtype=tf.float32, name='dense_3_target_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_4_input
# INFO:tensorflow:KerasCrossShard: <tensorflow.python.keras.optimizers.Adam object at 0x7f76df8547b8> []
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 1.6271388530731201 secs
# 10000/10000 [==============================] - 8s 820us/sample - loss: 0.6477 - acc: 0.7974
# loss: 0.648
# acc: 0.797

# %%
# 추론할 이미지 표시
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(test_images[i])
plt.show()

# 추론한 라벨 표시
test_predictions = tpu_model.predict(test_images[0:16]) # 학습 데이터 수를 16개로 늘림
test_predictions = np.argmax(test_predictions, axis=1)[0:10] # 결과 수를 10개로 줄임
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
        'dog', 'frog', 'horse', 'ship', 'truck']
print([labels[n] for n in test_predictions])
# Out:
# INFO:tensorflow:New input shapes; (re-)compiling: mode=infer (# of cores 8), [TensorSpec(shape=(2, 32, 32, 3), dtype=tf.float32, name='conv2d_4_input_10')]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Cloning Adam {'lr': 0.0010000000474974513, 'beta_1': 0.8999999761581421, 'beta_2': 0.9990000128746033, 'decay': 0.0, 'epsilon': 1e-07, 'amsgrad': False}
# INFO:tensorflow:Remapping placeholder for conv2d_4_input
# INFO:tensorflow:Started compiling
# INFO:tensorflow:Finished compiling. Time elapsed: 2.6365482807159424 secs
# ['cat', 'ship', 'ship', 'airplane', 'frog', 'frog', 'automobile', 'frog', 'cat', 'automobile']
