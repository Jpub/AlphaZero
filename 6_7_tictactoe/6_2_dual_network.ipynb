# %%
# dual_network.py 업로드
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7f0a27b4-932d-4b60-854a-49f178fa9953" name="files[]" multiple disabled />
#      <output id="result-7f0a27b4-932d-4b60-854a-49f178fa9953">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dual_network.py to dual_network.py

# %%
# 폴더 확인
# !dir
# Out:
# dual_network.py  game.py  sample_data

# %%
# dual_network.p 동작 확인
# !python dual_network.py
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0728 08:12:14.316224 140056526428032 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 2019-07-28 08:12:14.398386: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-07-28 08:12:14.400245: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2f95b80 executing computations on platform Host. Devices:
# 2019-07-28 08:12:14.400303: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# ...

# %%
# 폴더 확인
# !dir
# !dir ./model/
# Out:
# dual_network.py  game.py  model  sample_data
# best.h5
